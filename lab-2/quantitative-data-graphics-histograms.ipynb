# %% [markdown]
# ### Run this cell first in order to re-import packages and datasets!
# We need to do this again because we have opened up a new Jupyter notebook so all of our old variables are lost.

# %%
## import modules

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

## load dataset

demo_data = pd.read_csv("datasets/DEMO_data.csv") #demographic data

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Task 1: Create a histogram of the data in the *RIDAGEYR* column

# %%
demo_data
# Out:
#        SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDRETH1  RIDRETH3  \
# 0     62161         7         2         1        22         3         3
# 1     62162         7         2         2         3         1         1
# 2     62163         7         2         1        14         5         6
# 3     62164         7         2         2        44         3         3
# 4     62165         7         2         2        14         4         4
# 5     62166         7         2         1         9         3         3
# 6     62167         7         2         1         0         5         6
# 7     62168         7         2         1         6         5         7
# 8     62169         7         2         1        21         5         6
# 9     62170         7         2         1        15         5         7
# 10    62171         7         2         1        14         1         1
# 11    62172         7         2         2        43         4         4
# ...

# %%
## pull out age values from dataframe and store in a list variable
value_list = demo_data["RIDAGEYR"]

# %%
value_list
# Out:
# 0       22
# 1        3
# 2       14
# 3       44
# 4       14
# 5        9
# 6        0
# 7        6
# 8       21
# 9       15
# 10      14
# 11      43
# 12       2
# 13      80
# 14       5
# 15      34
# 16      51
# 17      80
# 18      55
# 19      35
# 20       9
# 21      75
# 22       6
# 23      26
# 24      16
# 25      17
# 26       9
# 27       2
# 28      30
# 29      15
#         ..
# 9726    68
# 9727    67
# 9728     5
# 9729    31
# 9730    54
# 9731     0
# 9732     3
# 9733    11
# 9734    31
# 9735     4
# 9736    68
# 9737    65
# 9738     3
# 9739    26
# 9740    48
# 9741    67
# 9742     6
# 9743    30
# 9744     8
# 9745     4
# 9746    80
# 9747    66
# 9748    28
# 9749     0
# 9750    27
# 9751    40
# 9752    18
# 9753    10
# 9754    60
# 9755    16
# Name: RIDAGEYR, Length: 9756, dtype: int64

# %%
## copy and paste the histogram code here
## replace value_list with your list of age values
## give the plot an appropriate plot title and axes labels

fig, axs = plt.subplots(figsize=(12,8))
axs.hist(value_list, color="SkyBlue", edgecolor="Black")
plt.title("Age", fontsize=20)
axs.set_xlabel("x element", fontsize=18)
axs.set_ylabel("Age", fontsize=18)
axs.tick_params(labelsize=15)
plt.show()

# %% [markdown]
# ## Task 2: More histograms

# %%
## load and display dataset

bmx_data = pd.read_csv("datasets/BMX_data.csv")
display(bmx_data.head())
# Out:
#     SEQN  BMDSTATS  BMXWT  BMIWT  BMXRECUM  BMIRECUM  BMXHEAD  BMIHEAD  BMXHT  \
# 0  62161         1   69.2    NaN       NaN       NaN      NaN      NaN  172.3
# 1  62163         1   49.4    NaN       NaN       NaN      NaN      NaN  168.9
# 2  62164         1   67.2    NaN       NaN       NaN      NaN      NaN  170.1
# 3  62165         1   69.1    NaN       NaN       NaN      NaN      NaN  159.4
# 4  62166         1   28.8    NaN       NaN       NaN      NaN      NaN  133.4
#
#    BMIHT    ...     BMXARMC  BMIARMC  BMXWAIST  BMIWAIST  BMXSAD1  BMXSAD2  \
# 0    NaN    ...        32.5      NaN      81.0       NaN     17.7     17.9
# 1    NaN    ...        22.0      NaN      64.6       NaN     15.6     15.5
# 2    NaN    ...        29.3      NaN      80.1       NaN     18.3     18.5
# 3    NaN    ...        29.7      NaN      86.7       NaN     21.0     20.8
# 4    NaN    ...        19.1      NaN      59.8       NaN     13.5     13.5
#
#    BMXSAD3  BMXSAD4  BMDAVSAD  BMDSADCM
# ...

# %% [markdown]
# ### Upper leg length histogram
# Upper leg length values are stored in the column named **BMXLEG**.

# %%
## pull out upper leg length values from dataframe and store in a list variable
value_list = bmx_data["BMXLEG"]

# %%
## copy and paste the histogram code here
## replace value_list with your list of upper leg length values
## give the plot an appropriate plot title and axes labels

fig, axs = plt.subplots(figsize=(12,8))
axs.hist(value_list, color="SkyBlue", edgecolor="Black")
plt.title("Upper leg length", fontsize=20)
axs.set_xlabel("X-axis label", fontsize=18)
axs.set_ylabel("Y-axis label", fontsize=18)
axs.tick_params(labelsize=15)
plt.show()

# %% [markdown]
# ### Height histogram
# Height values are stored in the column named **BMXHT**.

# %%
## pull out height values from dataframe and store in a list variable

# %%
## copy and paste the histogram code here
## replace value_list with your list of height values
## give the plot an appropriate plot title and axes labels

# %% [markdown]
# ### BMI histogram
# BMI values are stored in the column named **BMXBMI**.

# %%
## pull out BMI values from dataframe and store in a list variable

# %%
## copy and paste the histogram code here
## replace value_list with your list of BMI values
## give the plot an appropriate plot title and axes labels
